# %% [markdown]
# # Machine-Readable Data Formats
#
# ## Recommendations and Best Practices for Biodiversity Informatics
#
# ### ***Giuditta Parolini, Data Scientist, Museum für Naturkunde Berlin***

# %% [markdown]
# ---

# %% [markdown]
# # Table of Contents
# * [Introduction](#intro)
# * [Section 1: The trouble with non-machine-readable data](#trouble)
#     * [1.1: Data published as a PDF file](#pdf)
#     * [1.2: Data published as a DOCX file](#docx)
# * [Section 2: Machine-readable data formats for tabular data](#tabular)
#     * [2.1: CSV, TSV](#csv)
#     * [2.2: XML](#xml)
#     * [2.3: JSON](#json)
# * [Section 3: Geo data](#geo)
# * [Section 4: Images](#geo)
# * [Section 5: Other media](#other)
# * [Section 6: Biodiversity specials](#specials)

# %% [markdown]
# ---

# %% [markdown]
# ## Introduction <a class="anchor" id="intro"></a>
#
# **This python notebook provides practical examples that illustrate the main points discussed in the Guide on machine-readable data.**
# <br>
#
# It allows readers to see what are the challenges posed by data that are not machine-readable and experience the pitfalls that can cause the generation of invalid files even when using machine-readable data formats like CSV. The notebook also describes how unstructured data, like digital images or other media, can be approached to provide, at least, some pieces of machine-readable information.
# <br>
#
# Throughout the notebook, examples will be illustrated using the dataset ***Mounted Specimens of the Historical Bird Collection at the Museum für Naturkunde Berlin*** (DOI: [10.7479/wwqn-gd04](https://doi.org/10.7479/wwqn-gd04)) and modifications of it. The dataset contains metadata for over 13000 images of mounted bird specimens belonging to the bird collection of the museum. The mounted specimens, which dates back to the 19th century, have been systematically photographed and their images and related metadata are distributed under a [CC0 Public Domain Dedication](https://creativecommons.org/publicdomain/zero/1.0/deed.en) license. A copy of the original dataset is available in the GitHub repository as dataset.csv.

# %% [markdown]
# ---

# %% [markdown]
# ## 1: The trouble with non-machine-readable data <a class="anchor" id="trouble"></a>
# As mentioned in the Guide Introduction, PDF and DOCX files are human-readable, but not really machine-readable and extracting data from them is a challenging and error-prone exercise. An example of this will be demonstrated in this section using a PDF and a DOCX documents containing an extract of the bird collection dataset and its metadata. The content of both files is the same. It will be shown how extracting the data, which would be immediately available in a .csv file, from the overall text and saving them in a machine-readable format can become a lengthy and troublesome business.

# %% [markdown]
# ### 1.1: Data published as a PDF file <a class="anchor" id="pdf"></a>

# %%
import tabula
df = tabula.io.read_pdf("PDF_doc_example.pdf", pages='all')
# Out:
# Error from tabula-java:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[5], line 2
#       1 import tabula
# ----> 2 df = tabula.io.read_pdf("PDF_doc_example.pdf", pages='all')
#
# File ~/miniconda3/lib/python3.11/site-packages/tabula/io.py:400, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, force_subprocess, options)
#     397     raise ValueError(f"{path} is empty. Check the file, or download it manually.")
#     399 try:
# --> 400     output = _run(
#     401         tabula_options,
#     402         java_options,
#     403         path,
#     404         encoding=encoding,
#     405         force_subprocess=force_subprocess,
#     406     )
#     407 finally:
#     408     if temporary:
#
# File ~/miniconda3/lib/python3.11/site-packages/tabula/io.py:86, in _run(options, java_options, path, encoding, force_subprocess)
#      83 elif set(java_options) - IGNORED_JAVA_OPTIONS:
#      84     logger.warning("java_options is ignored until rebooting the Python process.")
# ---> 86 return _tabula_vm.call_tabula_java(options, path)
#
# File ~/miniconda3/lib/python3.11/site-packages/tabula/backend.py:122, in SubprocessTabula.call_tabula_java(self, options, path)
#     119     args.append(path)
#     121 try:
# --> 122     result = subprocess.run(
#     123         args,
#     124         stdout=subprocess.PIPE,
#     125         stderr=subprocess.PIPE,
#     126         stdin=subprocess.DEVNULL,
#     127         check=True,
#     128     )
#     129     if result.stderr:
#     130         logger.warning(f"Got stderr: {result.stderr.decode(self.encoding)}")
#
# File ~/miniconda3/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['java', '-Djava.awt.headless=true', '-Dfile.encoding=UTF8', '-jar', '/Users/giuditta.parolini/miniconda3/lib/python3.11/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar', '--pages', 'all', '--guess', '--format', 'JSON', 'PDF_doc_example.pdf']' returned non-zero exit status 1.

# %% [markdown]
# ### 1.2: Data published as a DOCX file <a class="anchor" id="docx"></a>

# %% [markdown]
# [Python-docx](https://python-docx.readthedocs.io/en/latest/api/document.html) is a library for creating DOCX files using the Python programming language. As the library is able to create a DOCX file, it is also useful to extract content from this type of files, i.e., the use case here considered.

# %%
# imports
import docx
import pandas as pd

# %%
# All the document content can be extracted as a generator object
content = docx.Document('DOCX_doc_example.docx').iter_inner_content()
content
# Out:
# <generator object BlockItemContainer.iter_inner_content at 0x113f9dc60>

# %%
# The generator object can be unpacked in a list to see all the components in the DOCX file.
# In our case, we have the text paragraphs and the data table
docx_list = [el for el in content]
docx_list
# Out:
# [<docx.text.paragraph.Paragraph at 0x14e98e4d0>,
#  <docx.text.paragraph.Paragraph at 0x113faf9d0>,
#  <docx.text.paragraph.Paragraph at 0x14e99c690>,
#  <docx.text.paragraph.Paragraph at 0x14e99ebd0>,
#  <docx.text.paragraph.Paragraph at 0x14e99f950>,
#  <docx.text.paragraph.Paragraph at 0x113f10e50>,
#  <docx.text.paragraph.Paragraph at 0x113f11d10>,
#  <docx.text.paragraph.Paragraph at 0x113f12f90>,
#  <docx.text.paragraph.Paragraph at 0x113f126d0>,
#  <docx.text.paragraph.Paragraph at 0x113f13150>,
#  <docx.text.paragraph.Paragraph at 0x113f12bd0>,
#  <docx.text.paragraph.Paragraph at 0x113f10710>,
#  <docx.text.paragraph.Paragraph at 0x113f13a50>,
#  <docx.text.paragraph.Paragraph at 0x113f12c10>,
#  <docx.text.paragraph.Paragraph at 0x113f10d90>,
#  <docx.text.paragraph.Paragraph at 0x113f12190>,
#  <docx.text.paragraph.Paragraph at 0x113f42350>,
#  <docx.table.Table at 0x113f40390>,
#  <docx.text.paragraph.Paragraph at 0x113f0b690>]

# %%
# It is easier to consider text paragraphs separated from the data table,
# so we remove the table from the list
docx_list.pop(17)
docx_list
# Out:
# [<docx.text.paragraph.Paragraph at 0x14e98e4d0>,
#  <docx.text.paragraph.Paragraph at 0x113faf9d0>,
#  <docx.text.paragraph.Paragraph at 0x14e99c690>,
#  <docx.text.paragraph.Paragraph at 0x14e99ebd0>,
#  <docx.text.paragraph.Paragraph at 0x14e99f950>,
#  <docx.text.paragraph.Paragraph at 0x113f10e50>,
#  <docx.text.paragraph.Paragraph at 0x113f11d10>,
#  <docx.text.paragraph.Paragraph at 0x113f12f90>,
#  <docx.text.paragraph.Paragraph at 0x113f126d0>,
#  <docx.text.paragraph.Paragraph at 0x113f13150>,
#  <docx.text.paragraph.Paragraph at 0x113f12bd0>,
#  <docx.text.paragraph.Paragraph at 0x113f10710>,
#  <docx.text.paragraph.Paragraph at 0x113f13a50>,
#  <docx.text.paragraph.Paragraph at 0x113f12c10>,
#  <docx.text.paragraph.Paragraph at 0x113f10d90>,
#  <docx.text.paragraph.Paragraph at 0x113f12190>,
#  <docx.text.paragraph.Paragraph at 0x113f42350>]

# %%
# Now the text content can be joined and printed.
# One can also save this information to a TXT file for later re-use
content = '\n'.join([p.text for p in docx_list])
print(content)
# Out:
# Dataset title
# Mounted Specimens of the Historical Bird Collection at the Museum für Naturkunde Berlin
#
# Creator
# MfN Digitization
#
# License
# CC0 1.0 Creative Commons Public Domain Dedication
#
# Dataset Description
# The dataset contains metadata for over 13000 images of mounted bird specimens belonging to the bird collection of the Museum für Naturkunde Berlin (MfN). The mounted specimens were mostly collected in the 19th century and have now been systematically photographed. For large part of the mounted specimens the full taxonomy is available. When this is not the case, the specimens are identified with their German common names. In the dataset there are birds from the well-known families of pigeons (Columbidae), parrots (Psittacidae) and pheasants (Phasianidae) as well as duck birds (Anatidae) and exotic hummingbirds (Trochilidae). Some rare specimens such as the quetzal (Pharomachrus mocinno) are also available in this dataset.
#
# Keywords
# Birds, mounted specimens, Museum für Naturkunde Berlin
#
# Table 1
# Shortened version of dataset, “Mounted Specimens of the Historical Bird Collection at the Museum für Naturkunde Berlin”, DOI: 10.7479/wwqn-gd04.

# %%
# Code inspired by Stackoverflow
# (https://stackoverflow.com/questions/46618718/python-docx-to-extract-table-from-word-docx)

# The table data can be extracted using a for loop and then saved into a pandas dataframe.
# The dataframe can then be saved as a CSV file. 

from timeit import default_timer as timer
from docx.api import Document

start = timer()

document = Document('DOCX_doc_example.docx')
table = document.tables[0]

data = []

keys = None
for i, row in enumerate(table.rows):
    text = (cell.text for cell in row.cells)

    if i == 0:
        keys = tuple(text)
        continue
    row_data = dict(zip(keys, text))
    data.append(row_data)

df = pd.DataFrame(data)

end = timer()

# %%
# Process time
print(end - start) #computed in seconds
# Out:
# 0.1035007839964237

# %% [markdown]
# It should be noted that 0.1s were required to recover 52(rows)*6(columns)=312 data cells,
# but the original dataset has 13288(rows)*15(columns)=199320 data cells.
# Assuming that the process time increases linearly with the number of cells
# (this is just an approximation and it is likely to underestimate the time required)
# process time would be about 63,88 seconds, i.e., 1,03 minutes. In contrast, reading the complete dataset in csv format with Python Pandas requires only 0.1 seconds (see below the cell execution time). Extracting the table data from the DOCX file is therefore >600 times slower than reading the data directly from the csv. Although times remain manageable for both solutions in this case, with datasets having millions and billions of data cells the data extraction si going to become more and more time expensive making the user regret not to have the data directly available in a machine-readable format like CSV.

# %%
# Reading in the entire dataset in machine-readable format
dataset_read_from_csv = pd.read_csv("dataset.csv")

# %%
dataset_read_from_csv
# Out:
#               catalogue_id                   key  \
# 0      ZMB_AVES_2000-14765  7d1264cca2e93009237e
# 1      ZMB_AVES_2000-14765  46e9071723ddbababd06
# 2      ZMB_AVES_2000-31350  cd50680edb26a356d7f1
# 3      ZMB_AVES_2000-31350  1af8bb8651519838f87c
# 4      ZMB_AVES_2000-31351  b2d8c2a150d82453d35c
# ...                    ...                   ...
# 13283        ZMB_Aves_9985  ca892e3d44beef9ca4dc
# 13284         ZMB_Aves_999  e76c936cca035eb8557d
# 13285         ZMB_Aves_999  e5672b9636cec6d995e8
# 13286        ZMB_Aves_9994  6ac8193d5913aa55de96
# 13287        ZMB_Aves_9994  11e23e572f87e978b590
#
#                         scientific_name  \
# 0                        Rhea americana
# 1                        Rhea americana
# 2                      Struthio camelus
# 3                      Struthio camelus
# 4                Struthio molybdophanes
# ...                                 ...
# 13283       Psittacula krameri borealis
# 13284        Falco biarmicus tanypterus
# 13285        Falco biarmicus tanypterus
# 13286  Psittacula longicauda longicauda
# 13287  Psittacula longicauda longicauda
#
#       title (scientific name or common name) class         family       genus  \
# 0                             Rhea americana  Aves        Rheidae        Rhea
# 1                             Rhea americana  Aves        Rheidae        Rhea
# 2                           Struthio camelus  Aves  Struthionidae    Struthio
# 3                           Struthio camelus  Aves  Struthionidae    Struthio
# 4                     Struthio molybdophanes  Aves  Struthionidae    Struthio
# ...                                      ...   ...            ...         ...
# 13283            Psittacula krameri borealis  Aves    Psittacidae  Psittacula
# 13284             Falco biarmicus tanypterus  Aves     Falconidae       Falco
# 13285             Falco biarmicus tanypterus  Aves     Falconidae       Falco
# 13286       Psittacula longicauda longicauda  Aves    Psittacidae  Psittacula
# 13287       Psittacula longicauda longicauda  Aves    Psittacidae  Psittacula
#
#                       species                        subspecies collections  \
# 0              Rhea americana                               NaN       Birds
# 1              Rhea americana                               NaN       Birds
# 2            Struthio camelus                               NaN       Birds
# 3            Struthio camelus                               NaN       Birds
# 4      Struthio molybdophanes                               NaN       Birds
# ...                       ...                               ...         ...
# 13283      Psittacula krameri       Psittacula krameri borealis       Birds
# 13284         Falco biarmicus        Falco biarmicus tanypterus       Birds
# 13285         Falco biarmicus        Falco biarmicus tanypterus       Birds
# 13286   Psittacula longicauda  Psittacula longicauda longicauda       Birds
# 13287   Psittacula longicauda  Psittacula longicauda longicauda       Birds
#
#        creation_year                                       absolute_url  \
# 0               2023  https://portal.museumfuernaturkunde.berlin/det...
# 1               2023  https://portal.museumfuernaturkunde.berlin/det...
# 2               2023  https://portal.museumfuernaturkunde.berlin/det...
# 3               2023  https://portal.museumfuernaturkunde.berlin/det...
# 4               2023  https://portal.museumfuernaturkunde.berlin/det...
# ...              ...                                                ...
# 13283           2023  https://portal.museumfuernaturkunde.berlin/det...
# 13284           2023  https://portal.museumfuernaturkunde.berlin/det...
# 13285           2023  https://portal.museumfuernaturkunde.berlin/det...
# 13286           2023  https://portal.museumfuernaturkunde.berlin/det...
# 13287           2023  https://portal.museumfuernaturkunde.berlin/det...
#
#                                    copyright  \
# 0      MfN Berlin, https://ror.org/052d1a351
# 1      MfN Berlin, https://ror.org/052d1a351
# 2      MfN Berlin, https://ror.org/052d1a351
# 3      MfN Berlin, https://ror.org/052d1a351
# 4      MfN Berlin, https://ror.org/052d1a351
# ...                                      ...
# 13283  MfN Berlin, https://ror.org/052d1a351
# 13284  MfN Berlin, https://ror.org/052d1a351
# 13285  MfN Berlin, https://ror.org/052d1a351
# 13286  MfN Berlin, https://ror.org/052d1a351
# 13287  MfN Berlin, https://ror.org/052d1a351
#
#                                                  license           authors
# 0      CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 1      CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 2      CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 3      CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 4      CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# ...                                                  ...               ...
# 13283  CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 13284  CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 13285  CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 13286  CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
# 13287  CC0 1.0 Creative Commons Public Domain Dedication  MfN Digitization
#
# [13288 rows x 15 columns]

# %%
df
# Out:
#            catalogue_id   title (scientific name or common name) class  \
# 0   ZMB_AVES_2000-14765                           Rhea americana  Aves
# 1   ZMB_AVES_2000-31350                         Struthio camelus  Aves
# 2   ZMB_AVES_2000-31351                   Struthio molybdophanes  Aves
# 3   ZMB_AVES_2000-31795                           Rhea americana  Aves
# 4   ZMB_AVES_2000-32382                             Rhea pennata  Aves
# 5   ZMB_AVES_2000-34658                         Struthio camelus  Aves
# 6   ZMB_AVES_2000-34923                           Rhea americana  Aves
# 7     ZMB_AVES_2000-632                         Struthio camelus  Aves
# 8     ZMB_AVES_2000-752               Casuarius unappendiculatus  Aves
# 9    ZMB_AVES_2000-8516                         Struthio camelus  Aves
# 10          ZMB_Aves_10                         Alectoris chukar  Aves
# 11         ZMB_Aves_100                        Calidris maritima  Aves
# 12       ZMB_Aves_10007           Psittacula alexandri alexandri  Aves
# 13       ZMB_Aves_10051          Alisterus scapularis scapularis  Aves
# 14        ZMB_Aves_1006                         Falco peregrinus  Aves
# 15       ZMB_Aves_10066      Trichoglossus moluccanus moluccanus  Aves
# 16       ZMB_Aves_10067      Trichoglossus moluccanus moluccanus  Aves
# 17       ZMB_Aves_10068      Trichoglossus moluccanus moluccanus  Aves
# 18       ZMB_Aves_10073                    Trichoglossus ornatus  Aves
# 19        ZMB_Aves_1009                  Falco peregrinus anatum  Aves
# 20         ZMB_Aves_101                Alectoris barbara barbara  Aves
# 21       ZMB_Aves_10101                      Strigops habroptila  Aves
# 22        ZMB_Aves_1012                         Falco peregrinus  Aves
# 23        ZMB_Aves_1013                         Falco peregrinus  Aves
# 24        ZMB_Aves_1015                         Falco peregrinus  Aves
# 25        ZMB_Aves_1016                         Falco peregrinus  Aves
# 26        ZMB_Aves_1017                         Falco peregrinus  Aves
# 27        ZMB_Aves_1019                         Falco peregrinus  Aves
# 28         ZMB_Aves_102                 Podiceps auritus auritus  Aves
# 29        ZMB_Aves_1020              Falco peregrinus peregrinus  Aves
# 30       ZMB_Aves_10206                         Psittacara euops  Aves
# 31       ZMB_Aves_10220            Cyanoliseus patagonus bloxami  Aves
# 32        ZMB_Aves_1023                  Falco peregrinus anatum  Aves
# 33        ZMB_Aves_1024              Falco peregrinus peregrinus  Aves
# 34        ZMB_Aves_1026              Falco peregrinus peregrinus  Aves
# 35        ZMB_Aves_1027                  Falco peregrinus anatum  Aves
# 36        ZMB_Aves_1029                Falco biarmicus feldeggii  Aves
# 37         ZMB_Aves_103                     Aythya marila marila  Aves
# 38        ZMB_Aves_1030                    Falco cherrug cherrug  Aves
# 39        ZMB_Aves_1031                    Falco cherrug cherrug  Aves
# 40        ZMB_Aves_1032                    Falco cherrug cherrug  Aves
# 41        ZMB_Aves_1033                    Falco cherrug cherrug  Aves
# 42        ZMB_Aves_1034                    Falco cherrug cherrug  Aves
# 43        ZMB_Aves_1035                    Falco cherrug cherrug  Aves
# 44        ZMB_Aves_1038                         Falco rusticolus  Aves
# 45        ZMB_Aves_1039                         Falco rusticolus  Aves
# 46        ZMB_Aves_1040                         Falco rusticolus  Aves
# 47        ZMB_Aves_1043                         Falco rusticolus  Aves
# 48        ZMB_Aves_1045                         Falco rusticolus  Aves
# 49        ZMB_Aves_1047                         Falco rusticolus  Aves
# 50        ZMB_Aves_1048                         Falco rusticolus  Aves
# 51         ZMB_Aves_105  Calandrella brachydactyla brachydactyla  Aves
#
#            family          genus                     species
# 0         Rheidae           Rhea              Rhea americana
# 1   Struthionidae       Struthio            Struthio camelus
# 2   Struthionidae       Struthio      Struthio molybdophanes
# 3         Rheidae           Rhea              Rhea americana
# 4         Rheidae           Rhea                Rhea pennata
# 5   Struthionidae       Struthio            Struthio camelus
# 6         Rheidae           Rhea              Rhea americana
# 7   Struthionidae       Struthio            Struthio camelus
# 8     Casuariidae      Casuarius  Casuarius unappendiculatus
# 9   Struthionidae       Struthio            Struthio camelus
# 10    Phasianidae      Alectoris            Alectoris chukar
# 11   Scolopacidae       Calidris           Calidris maritima
# 12    Psittacidae     Psittacula        Psittacula alexandri
# 13    Psittacidae      Alisterus        Alisterus scapularis
# 14     Falconidae          Falco         Falco pelegrinoides
# 15    Psittacidae  Trichoglossus    Trichoglossus moluccanus
# 16    Psittacidae  Trichoglossus    Trichoglossus moluccanus
# 17    Psittacidae  Trichoglossus    Trichoglossus moluccanus
# 18    Psittacidae  Trichoglossus       Trichoglossus ornatus
# 19     Falconidae          Falco            Falco peregrinus
# 20    Phasianidae      Alectoris           Alectoris barbara
# 21    Strigopidae       Strigops         Strigops habroptila
# 22     Falconidae          Falco            Falco peregrinus
# 23     Falconidae          Falco            Falco peregrinus
# 24     Falconidae          Falco            Falco peregrinus
# 25     Falconidae          Falco            Falco peregrinus
# 26     Falconidae          Falco            Falco peregrinus
# 27     Falconidae          Falco            Falco peregrinus
# 28  Podicipedidae       Podiceps            Podiceps auritus
# 29     Falconidae          Falco            Falco peregrinus
# 30    Psittacidae     Psittacara            Psittacara euops
# 31    Psittacidae    Cyanoliseus       Cyanoliseus patagonus
# 32     Falconidae          Falco            Falco peregrinus
# 33     Falconidae          Falco            Falco peregrinus
# 34     Falconidae          Falco            Falco peregrinus
# 35     Falconidae          Falco            Falco peregrinus
# 36     Falconidae          Falco             Falco biarmicus
# 37       Anatidae         Aythya               Aythya marila
# 38     Falconidae          Falco               Falco cherrug
# 39     Falconidae          Falco               Falco cherrug
# 40     Falconidae          Falco               Falco cherrug
# 41     Falconidae          Falco               Falco cherrug
# 42     Falconidae          Falco               Falco cherrug
# 43     Falconidae          Falco               Falco cherrug
# 44     Falconidae          Falco            Falco rusticolus
# 45     Falconidae          Falco            Falco rusticolus
# 46     Falconidae          Falco            Falco rusticolus
# 47     Falconidae          Falco            Falco rusticolus
# 48     Falconidae          Falco            Falco rusticolus
# 49     Falconidae          Falco            Falco rusticolus
# 50     Falconidae          Falco            Falco rusticolus
# 51      Alaudidae    Calandrella   Calandrella brachydactyla

# %% [markdown]
# The dataframe is well-formed and there is no issue in the data extraction, however the data have been extracted looping over the table element in the DOCX file. Loops are inefficient in Python and while in this case there is no real time issue with a very small table, problems would immediately emerge when real-scale datasets with thousands of rows and tens of columns needed to be extracted.

# %% [markdown]
# ---

# %% [markdown]
# ## 2: Machine-readable data formats for tabular data <a class="anchor" id="tabular"></a>

# %% [markdown]
# CSV files might not be the solution to all data problems, but they are definitely handy for delivering tabular data in a machine-readable format. For datasets with up to 1 Million data rows they should be the first data format considered.
